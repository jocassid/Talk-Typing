# %%
import sys
print(sys.version)
dir(sys)
# Out:
# 3.10.12 (main, May 27 2025, 17:12:29) [GCC 11.4.0]
# ['__breakpointhook__',
#  '__displayhook__',
#  '__doc__',
#  '__excepthook__',
#  '__interactivehook__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__spec__',
#  '__stderr__',
#  '__stdin__',
#  '__stdout__',
#  '__unraisablehook__',
#  '_base_executable',
#  '_clear_type_cache',
#  '_current_exceptions',
#  '_current_frames',
#  '_deactivate_opcache',
#  '_debugmallocstats',
#  '_framework',
#  '_getframe',
#  '_git',
#  '_home',
#  '_xoptions',
#  'abiflags',
#  'addaudithook',
#  'api_version',
#  'argv',
#  'audit',
#  'base_exec_prefix',
#  'base_prefix',
#  'breakpointhook',
#  'builtin_module_names',
#  'byteorder',
#  'call_tracing',
#  'copyright',
#  'displayhook',
#  'dont_write_bytecode',
#  'exc_info',
#  'excepthook',
#  'exec_prefix',
#  'executable',
#  'exit',
#  'flags',
#  'float_info',
#  'float_repr_style',
#  'get_asyncgen_hooks',
#  'get_coroutine_origin_tracking_depth',
# ...

# %% [markdown]
# # A Brief History of Python Typing

# %% [markdown]
# *In the beginning, there was ...*

# %% [markdown]
# PEP 3107 – Function Annotations
# https://peps.python.org/pep-3107/
# "a syntax for adding arbitrary metadata annotations to Python function"
# 02-Dec-2006
# implemented in Python3
# Established the ':' EXPRESSION syntax.  Did not say anything about what expressions to use (left that to 3rd party libraries and tools)

# %%
# PEP 3107 - example 1
def compile(source: "something compilable",
            filename: "where the compilable thing comes from",
            mode: "is this a single statement or a suite?"):
    ...

# %%
help(compile)
# Out:
# Help on function compile in module __main__:
#
# compile(source: 'something compilable', filename: 'where the compilable thing comes from', mode: 'is this a single statement or a suite?')
#     # PEP 3107 - example 1

# %%
# in some library
class Haulable:
    ...

class PackAnimal:
    ...

class Distance:
    ...

# %%
# PEP 3107 - example2
def haul(item: Haulable, *vargs: PackAnimal) -> Distance:
    ...

# %%
help(haul)
# Out:
# Help on function haul in module __main__:
#
# haul(item: __main__.Haulable, *vargs: __main__.PackAnimal) -> __main__.Distance
#     # PEP 3107 - example2

# %%
def foo(a: 5 + 2) -> 3 -1 :
    ...

# %%
help(foo)
# Out:
# Help on function foo in module __main__:
#
# foo(a: 7) -> 2
